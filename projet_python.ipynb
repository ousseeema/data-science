# %% [markdown]
# <a href="https://colab.research.google.com/github/ousseeema/data-science/blob/main/projet_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imporation de pandas , numpy, matplotlib,seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the files
data = pd.read_excel("imap_export.xls")
#project the dataframe
data
# Out:
#     Data Export - Filters applied:    (none) Data As Of Aug 2024  \
# 0                                         Factory Name
# 1                               EVEREST TEXTILE CO LTD
# 2                                      Big Game Sports
# 3                                  PT Semarang Garment
# 4                           Charmgo (Cambodia) Co. Ltd
# ..                                                 ...
# 632                      PT Victory Chingluh Indonesia
# 633                 Olive Apparel (Cambodia) Co., Ltd.
# 634                            PT. Kanindo Makmur Jaya
# 635                       South Island Garment Sdn Bhd
# 636                      Toyama Sports Goods Co., Ltd.
#
#          Unnamed: 1         Unnamed: 2           Unnamed: 3  Unnamed: 4  \
# 0      Factory Type  Product Type Type  Nike, Inc. Brand(s)      Events
# 1         MATERIALS            Apparel                 Nike         NaN
# 2    FINISHED GOODS          Equipment                 Nike  Collegiate
# 3    FINISHED GOODS            Apparel                 Nike         NaN
# 4    FINISHED GOODS            Apparel                 Nike         NaN
# ..              ...                ...                  ...         ...
# 632  FINISHED GOODS           Footwear                 Nike         NaN
# 633  FINISHED GOODS            Apparel                 Nike         NaN
# 634  FINISHED GOODS          Equipment                 Nike  Collegiate
# 635  FINISHED GOODS            Apparel                 Nike  Collegiate
# 636  FINISHED GOODS          Equipment                 Nike         NaN
#
#           Unnamed: 5                                         Unnamed: 6  \
# 0     Supplier Group                                            Address
# 1    EVEREST TEXTILE                              No 256 Minghe Village
# 2    BIG GAME SPORTS                                     13835 Welch Rd
# 3            KUKDONG                            JL Soekarno Hatta Km 25
# 4            CHARMGO  Pham Bostanei Kuhn Kaheing Srok Samrongtong Ka...
# ..               ...                                                ...
# 632        CHING LUH                           JL Raya Pasarkemis Rajeg
# 633          RAMATEX                National Road No 3 Phum Prey Kambot
# 634           KANAAN                            Jalan Raya Jepara Kudus
# 635     SOUTH ISLAND                          2468 Solok Perusahaan Dua
# 636    TOYAMA SPORTS                                      345 Fukumitsu
#
#        Unnamed: 7     Unnamed: 8   Unnamed: 9       Unnamed: 10 Unnamed: 11  \
# 0            City          State  Postal Code  Country / Region      Region
# 1     Tainan City         Tainan       743002            Taiwan      N ASIA
# 2          Dallas          Texas        75244               USA    AMERICAS
# 3        Semarang    Jawa Tengah        50552         Indonesia      S ASIA
# 4    Kampong Spey  Kampong Spueu        05207          Cambodia     SE ASIA
# ..            ...            ...          ...               ...         ...
# 632     Tangerang         Banten        15560         Indonesia      S ASIA
# 633    Phnom Penh     Phnom Penh       120910          Cambodia     SE ASIA
# 634        Jepara    Jawa Tengah        59462         Indonesia      S ASIA
# 635         Perai   Pulau Pinang        13600          Malaysia      S ASIA
# 636         Nanto         Toyama     939-1637             Japan      N ASIA
#
#        Unnamed: 12   Unnamed: 13       Unnamed: 14        Unnamed: 15
# 0    Total Workers  Line Workers  % Female Workers  % Migrant Workers
# 1             1439           811                51                 57
# 2               68            51                36                  0
# 3             3851          3462                94                  0
# 4             1557          1526                71                  1
# ..             ...           ...               ...                ...
# 632           4014          3475                55                  0
# 633           1274          1107                89                  0
# 634           6680          6582                62                  0
# 635            621           344                53                 82
# 636              3             2                 0                  0
#
# [637 rows x 16 columns]

# %%
# We noticed that the column names are in the first row, so we reset the format by assigning the first row as column names.
# Then, we removed the first row (which contained the column names) from the data and reset the index.
data.columns=["Factory Name","Factory Type","Product Type","Brand","Events","Supplier Group","Address","City","State","Postal Code","Country","Region","Total Workers","Line Workers","Female Workers","Migrant Workers"]
data = data.iloc[1:]
data= data.reset_index(drop=True)
data.head()
# Out:
#                  Factory Name    Factory Type Product Type Brand      Events  \
# 0      EVEREST TEXTILE CO LTD       MATERIALS      Apparel  Nike         NaN
# 1             Big Game Sports  FINISHED GOODS    Equipment  Nike  Collegiate
# 2         PT Semarang Garment  FINISHED GOODS      Apparel  Nike         NaN
# 3  Charmgo (Cambodia) Co. Ltd  FINISHED GOODS      Apparel  Nike         NaN
# 4      SAN FANG (TR1) (CHINA)       MATERIALS     Footwear  Nike         NaN
#
#     Supplier Group                                            Address  \
# 0  EVEREST TEXTILE                              No 256 Minghe Village
# 1  BIG GAME SPORTS                                     13835 Welch Rd
# 2          KUKDONG                            JL Soekarno Hatta Km 25
# 3          CHARMGO  Pham Bostanei Kuhn Kaheing Srok Samrongtong Ka...
# 4         SAN FANG                           YUE YUEN INDUSTRIAL PARK
#
#                   City          State Postal Code    Country    Region  \
# 0          Tainan City         Tainan      743002     Taiwan    N ASIA
# 1               Dallas          Texas       75244        USA  AMERICAS
# 2             Semarang    Jawa Tengah       50552  Indonesia    S ASIA
# 3         Kampong Spey  Kampong Spueu       05207   Cambodia   SE ASIA
# 4  DONGGUAN, GUANGDONG      Guangdong      511700      China    N ASIA
#
#   Total Workers Line Workers Female Workers Migrant Workers
# 0          1439          811             51              57
# 1            68           51             36               0
# 2          3851         3462             94               0
# 3          1557         1526             71               1
# 4           307          225             20               0

# %%
#info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Factory Name     636 non-null    object
#  1   Factory Type     636 non-null    object
#  2   Product Type     636 non-null    object
#  3   Brand            636 non-null    object
#  4   Events           148 non-null    object
#  5   Supplier Group   636 non-null    object
#  6   Address          636 non-null    object
#  7   City             635 non-null    object
#  8   State            636 non-null    object
#  9   Postal Code      636 non-null    object
#  10  Country          636 non-null    object
#  11  Region           636 non-null    object
#  12  Total Workers    636 non-null    object
#  13  Line Workers     636 non-null    object
#  14  Female Workers   636 non-null    object
#  15  Migrant Workers  636 non-null    object
# dtypes: object(16)
# memory usage: 79.6+ KB

# %%
#Delete unnecessary columns,Replace NaN values with a specific value
data.fillna({'Events':"Collegiate"}, inplace= True)
data.drop(["Address","Postal Code"], axis=1, inplace= True)
data.head()
# Out:
#                  Factory Name    Factory Type Product Type Brand      Events  \
# 0      EVEREST TEXTILE CO LTD       MATERIALS      Apparel  Nike  Collegiate
# 1             Big Game Sports  FINISHED GOODS    Equipment  Nike  Collegiate
# 2         PT Semarang Garment  FINISHED GOODS      Apparel  Nike  Collegiate
# 3  Charmgo (Cambodia) Co. Ltd  FINISHED GOODS      Apparel  Nike  Collegiate
# 4      SAN FANG (TR1) (CHINA)       MATERIALS     Footwear  Nike  Collegiate
#
#     Supplier Group                 City          State    Country    Region  \
# 0  EVEREST TEXTILE          Tainan City         Tainan     Taiwan    N ASIA
# 1  BIG GAME SPORTS               Dallas          Texas        USA  AMERICAS
# 2          KUKDONG             Semarang    Jawa Tengah  Indonesia    S ASIA
# 3          CHARMGO         Kampong Spey  Kampong Spueu   Cambodia   SE ASIA
# 4         SAN FANG  DONGGUAN, GUANGDONG      Guangdong      China    N ASIA
#
#   Total Workers Line Workers Female Workers Migrant Workers
# 0          1439          811             51              57
# 1            68           51             36               0
# 2          3851         3462             94               0
# 3          1557         1526             71               1
# 4           307          225             20               0

# %%
# Adding a column that contains the number of male workers and the total number of workers excluding immigrants.
data["Male Workers"]= data["Total Workers"] - data["Female Workers"]
data["Total Workers excluding immigrants"]= data["Total Workers"] - data["Migrant Workers"]
data.head()
# Out:
#                  Factory Name    Factory Type Product Type Brand      Events  \
# 0      EVEREST TEXTILE CO LTD       MATERIALS      Apparel  Nike  Collegiate
# 1             Big Game Sports  FINISHED GOODS    Equipment  Nike  Collegiate
# 2         PT Semarang Garment  FINISHED GOODS      Apparel  Nike  Collegiate
# 3  Charmgo (Cambodia) Co. Ltd  FINISHED GOODS      Apparel  Nike  Collegiate
# 4      SAN FANG (TR1) (CHINA)       MATERIALS     Footwear  Nike  Collegiate
#
#     Supplier Group                 City          State    Country    Region  \
# 0  EVEREST TEXTILE          Tainan City         Tainan     Taiwan    N ASIA
# 1  BIG GAME SPORTS               Dallas          Texas        USA  AMERICAS
# 2          KUKDONG             Semarang    Jawa Tengah  Indonesia    S ASIA
# 3          CHARMGO         Kampong Spey  Kampong Spueu   Cambodia   SE ASIA
# 4         SAN FANG  DONGGUAN, GUANGDONG      Guangdong      China    N ASIA
#
#   Total Workers Line Workers Female Workers Migrant Workers Male Workers  \
# 0          1439          811             51              57         1388
# 1            68           51             36               0           32
# 2          3851         3462             94               0         3757
# 3          1557         1526             71               1         1486
# 4           307          225             20               0          287
#
#   Total Workers excluding immigrants
# 0                               1382
# 1                                 68
# 2                               3851
# 3                               1556
# 4                                307

# %%
# how many type of factory we have
res= data['Factory Type'].nunique()
print('We have ', res ,"type of factory ")
# how many factory we have in each factory type
res1= data['Factory Type'].value_counts()
print("In each type we have :")
res1
# Out:
# We have  3 type of factory
# In each type we have :
# Factory Type
# FINISHED GOODS                 461
# MATERIALS                      126
# FINISHED GOODS - COMPONENTS     49
# Name: count, dtype: int64

# %%
#how manay type of product we have
res2= data['Product Type'].nunique()
print('We have ', res2 ,"type of product ")
#how many factory we have in each product type
res3 = data["Product Type"].value_counts()
print("In each type we have :")
res3
# Out:
# We have  3 type of product
# In each type we have :
# Product Type
# Apparel      354
# Footwear     208
# Equipment     74
# Name: count, dtype: int64

# %%
#how many brand we have
res4= data['Brand'].nunique()
print('We have ', res4 ,"brand ")
#how many factory we have in each brand
res5 = data["Brand"].value_counts()
print("In each brand we have :")
res5
# Out:
# We have  2 brand
# In each brand we have :
# Brand
# Nike        602
# Converse     34
# Name: count, dtype: int64

# %%
# how many country we have
print(data["Country"].unique())
# how many factory in each country
res6 = data["Country"].value_counts()
print("In each country we have :")
res6
# Out:
# ['Taiwan' 'USA' 'Indonesia' 'Cambodia' 'China' 'Vietnam' 'Thailand'
#  'Italy' 'South Korea' 'Pakistan' 'Bosnia' 'Brazil' 'Jordan' 'Egypt'
#  'India' 'Japan' 'Sri Lanka' 'Argentina' 'Mexico' 'Guatemala'
#  'Philippines' 'Georgia' 'Honduras' 'El Salvador' 'Turkey' 'Moldova'
#  'Malaysia' 'South Africa' 'Spain' 'Nicaragua' 'France' 'Canada'
#  'United Kingdom' 'Netherlands' 'Lithuania' 'Israel']
# In each country we have :
# Country
# Vietnam           159
# China             152
# Indonesia          54
# Taiwan             32
# Thailand           29
# USA                25
# Cambodia           22
# Sri Lanka          22
# South Korea        18
# Brazil             14
# Italy              13
# India              12
# Japan               9
# Mexico              8
# Egypt               8
# Argentina           7
# Turkey              6
# El Salvador         6
# Malaysia            5
# Pakistan            5
# Guatemala           5
# Jordan              5
# Georgia             3
# Honduras            3
# Moldova             2
# Philippines         2
# Bosnia              1
# South Africa        1
# Spain               1
# Nicaragua           1
# France              1
# Canada              1
# United Kingdom      1
# Netherlands         1
# Lithuania           1
# Israel              1
# Name: count, dtype: int64

# %%
#how many region we have
res7 = data['Region'].unique()
print(" in matter of region , we have  ", res7)
# how many factory in each region
res8 = data["Region"].value_counts()
print("In each region we have :")
res8
# Out:
#  in matter of region , we have   ['N ASIA' 'AMERICAS' 'S ASIA' 'SE ASIA' 'EMEA']
# In each region we have :
# Region
# N ASIA      213
# SE ASIA     210
# S ASIA       98
# AMERICAS     70
# EMEA         45
# Name: count, dtype: int64

# %%
data.head()
# Out:
#              Factory Name Factory Type Product Type Brand      Events  \
# 0  EVEREST TEXTILE CO LTD    MATERIALS      Apparel  Nike  Collegiate
#
#     Supplier Group         City   State Country  Region Total Workers  \
# 0  EVEREST TEXTILE  Tainan City  Tainan  Taiwan  N ASIA          1439
#
#   Line Workers Female Workers Migrant Workers Male Workers  \
# 0          811             51              57         1388
#
#   Total Workers excluding immigrants
# 0                               1382

# %%
# how many total workers in details (each country)
res9 = data.groupby("Country").agg({"Total Workers": "sum", "Line Workers": "sum", "Female Workers":"sum",  "Male Workers":"sum","Migrant Workers":"sum","Total Workers excluding immigrants":"sum"  })
res9
# Out:
#                Total Workers Line Workers Female Workers Male Workers  \
# Country
# Argentina               1658         1328            400         1258
# Bosnia                  1998         1835             71         1927
# Brazil                 20449        15687            874        19575
# Cambodia               56259        48840           1551        54708
# Canada                   255          200             80          175
# China                 135863       109267           9415       126448
# Egypt                  14091        10642            379        13712
# El Salvador             7127         5842            252         6875
# France                    13            9             62          -49
# Georgia                 4150         3815            285         3865
# Guatemala               5282         4908            292         4990
# Honduras                8295         6633            110         8185
# India                  43246        38866            643        42603
# Indonesia             284480       248728           3500       280980
# Israel                   205           13             60          145
# Italy                   1594         1133            877          717
# Japan                   2067         1716            414         1653
# Jordan                  7202         6280            364         6838
# Lithuania                310          258             91          219
# Malaysia                7334         6487            164         7170
# Mexico                  6307         5111            421         5886
# Moldova                 1062          850            192          870
# Netherlands               31           23             42          -11
# Nicaragua               4634         4317             57         4577
# Pakistan               48495        44642             61        48434
# Philippines             2335         1481             84         2251
# South Africa             195          187             90          105
# South Korea             3043         1187            411         2632
# Spain                     16           13             50          -34
# Sri Lanka              36769        29401           1158        35611
# Taiwan                 12209         6169           1477        10732
# Thailand               25761        21331           1795        23966
# Turkey                  5564         3404            362         5202
# USA                     3591         2823           1652         1939
# United Kingdom            90           90             60           30
# Vietnam               494587       430654          10191       484396
#
#                Migrant Workers Total Workers excluding immigrants
# Country
# Argentina                   73                               1585
# Bosnia                       0                               1998
# Brazil                      85                              20364
# Cambodia                    53                              56206
# Canada                       5                                250
# China                      413                             135450
# Egypt                       15                              14076
# El Salvador                  1                               7126
# France                     100                                -87
# Georgia                      0                               4150
# Guatemala                    0                               5282
# Honduras                     1                               8294
# India                        0                              43246
# Indonesia                   82                             284398
# Israel                       0                                205
# Italy                       87                               1507
# Japan                       96                               1971
# Jordan                     354                               6848
# Lithuania                    2                                308
# Malaysia                   429                               6905
# Mexico                       0                               6307
# Moldova                      0                               1062
# Netherlands                 61                                -30
# Nicaragua                    0                               4634
# Pakistan                     0                              48495
# Philippines                  0                               2335
# South Africa                 0                                195
# South Korea                114                               2929
# Spain                        0                                 16
# Sri Lanka                    2                              36767
# Taiwan                     815                              11394
# Thailand                  1088                              24673
# Turkey                       0                               5564
# USA                         37                               3554
# United Kingdom               0                                 90
# Vietnam                    305                             494282

# %%
# the maximum  workers in details (each country)
res10 = data.groupby("Country").agg({"Total Workers": "max", "Line Workers": "max", "Female Workers":"max",  "Male Workers":"max","Migrant Workers":"max","Total Workers excluding immigrants":"max"  })
res10
# Out:
#                Total Workers Line Workers Female Workers Male Workers  \
# Country
# Argentina                810          700             80          765
# Bosnia                  1998         1835             71         1927
# Brazil                  5554         5084             88         5501
# Cambodia               17415        15944             95        17327
# Canada                   255          200             80          175
# China                  11136         9039            100        11047
# Egypt                   3925         3030             83         3896
# El Salvador             2643         2041             68         2575
# France                    13            9             62          -49
# Georgia                 1542         1414             97         1446
# Guatemala               3422         3091             63         3359
# Honduras                5413         3901             54         5359
# India                   6900         6500             91         6820
# Indonesia              27904        24373            100        27817
# Israel                   205           13             60          145
# Italy                    384          241             93          342
# Japan                   1700         1400             92         1660
# Jordan                  1853         1682             87         1784
# Lithuania                310          258             91          219
# Malaysia                3678         3301             53         3663
# Mexico                  2088         1790             79         2035
# Moldova                  670          537             97          573
# Netherlands               31           23             42          -11
# Nicaragua               4634         4317             57         4577
# Pakistan               20031        19474             18        20013
# Philippines             2151         1329             44         2111
# South Africa             195          187             90          105
# South Korea              983          315             63          931
# Spain                     16           13             50          -34
# Sri Lanka               5552         4782            100         5469
# Taiwan                  1875         1442            100         1830
# Thailand                3293         3207             79         3221
# Turkey                  3671         2122             88         3618
# USA                      512          417             95          447
# United Kingdom            90           90             60           30
# Vietnam                29272        25978             98        29195
#
#                Migrant Workers Total Workers excluding immigrants
# Country
# Argentina                   60                                750
# Bosnia                       0                               1998
# Brazil                      76                               5554
# Cambodia                    26                              17412
# Canada                       5                                250
# China                      100                              11136
# Egypt                       11                               3914
# El Salvador                  1                               2643
# France                     100                                -87
# Georgia                      0                               1542
# Guatemala                    0                               3422
# Honduras                     1                               5413
# India                        0                               6900
# Indonesia                   25                              27904
# Israel                       0                                205
# Italy                       31                                381
# Japan                       47                               1700
# Jordan                      96                               1775
# Lithuania                    2                                308
# Malaysia                    99                               3607
# Mexico                       0                               2088
# Moldova                      0                                670
# Netherlands                 61                                -30
# Nicaragua                    0                               4634
# Pakistan                     0                              20031
# Philippines                  0                               2151
# South Africa                 0                                195
# South Korea                 33                                983
# Spain                        0                                 16
# Sri Lanka                    2                               5552
# Taiwan                      70                               1875
# Thailand                   100                               3293
# Turkey                       0                               3671
# USA                         25                                512
# United Kingdom               0                                 90
# Vietnam                    100                              29272

# %%
# the minimum workers in details (each country)
res11 = data.groupby("Country").agg({"Total Workers": "min", "Line Workers": "min", "Female Workers":"min",  "Male Workers":"min","Migrant Workers":"min","Total Workers excluding immigrants":"min"  })
res11
# Out:
#                Total Workers Line Workers Female Workers Male Workers  \
# Country
# Argentina                 21           17             30          -59
# Bosnia                  1998         1835             71         1927
# Brazil                    44           22             39            2
# Cambodia                  30           23              0          -65
# Canada                   255          200             80          175
# China                      2            1              0          -57
# Egypt                    265          206             20          206
# El Salvador              373          311              0          313
# France                    13            9             62          -49
# Georgia                 1142         1049             92         1045
# Guatemala                153          146             56           97
# Honduras                 950          800             21          915
# India                     28           21              0           28
# Indonesia                 37           20              6           -8
# Israel                   205           13             60          145
# Italy                     11            8             15          -80
# Japan                      3            1              0          -53
# Jordan                   590          442             53          510
# Lithuania                310          258             91          219
# Malaysia                 621          344             15          568
# Mexico                   268          238              0          198
# Moldova                  392          313             95          297
# Netherlands               31           23             42          -11
# Nicaragua               4634         4317             57         4577
# Pakistan                3915         3371              1         3898
# Philippines              184          152             40          140
# South Africa             195          187             90          105
# South Korea               11            1              0          -16
# Spain                     16           13             50          -34
# Sri Lanka                156           96              0           71
# Taiwan                     2            1              0          -86
# Thailand                   2            1              1            1
# Turkey                    74           66             43            9
# USA                       21           10             24          -58
# United Kingdom            90           90             60           30
# Vietnam                    2            1              0          -49
#
#                Migrant Workers Total Workers excluding immigrants
# Country
# Argentina                    0                                 21
# Bosnia                       0                               1998
# Brazil                       0                                 44
# Cambodia                     0                                  4
# Canada                       5                                250
# China                        0                                -98
# Egypt                        0                                265
# El Salvador                  0                                373
# France                     100                                -87
# Georgia                      0                               1142
# Guatemala                    0                                153
# Honduras                     0                                949
# India                        0                                 28
# Indonesia                    0                                 12
# Israel                       0                                205
# Italy                        0                                 -7
# Japan                        0                                 -8
# Jordan                      34                                556
# Lithuania                    2                                308
# Malaysia                    71                                539
# Mexico                       0                                268
# Moldova                      0                                392
# Netherlands                 61                                -30
# Nicaragua                    0                               4634
# Pakistan                     0                               3915
# Philippines                  0                                184
# South Africa                 0                                195
# South Korea                  0                                 -9
# Spain                        0                                 16
# Sri Lanka                    0                                156
# Taiwan                       0                                -26
# Thailand                     0                                -98
# Turkey                       0                                 74
# USA                          0                                 21
# United Kingdom               0                                 90
# Vietnam                      0                                -98

# %%
# # how many total workers in details (each region)
res12 = data.groupby("Region").agg({"Total Workers": "sum", "Line Workers": "sum", "Female Workers":"sum",  "Male Workers":"sum","Migrant Workers":"sum","Total Workers excluding immigrants":"sum"  })
res12
# Out:
#          Total Workers Line Workers Female Workers Male Workers  \
# Region
# AMERICAS         57598        46849           4138        53460
# EMEA             36521        28552           2985        33536
# N ASIA          155517       119820          11801       143716
# S ASIA          420324       368124           5526       414798
# SE ASIA         576607       500825          13537       563070
#
#          Migrant Workers Total Workers excluding immigrants
# Region
# AMERICAS             202                              57396
# EMEA                 619                              35902
# N ASIA              1438                             154079
# S ASIA               513                             419811
# SE ASIA             1446                             575161

# %%
# the maximum workers in details (each region)
res13 = data.groupby("Region").agg({"Total Workers": "max", "Line Workers": "max", "Female Workers":"max",  "Male Workers":"max","Migrant Workers":"max","Total Workers excluding immigrants":"max"  })
res13
# Out:
#          Total Workers Line Workers Female Workers Male Workers  \
# Region
# AMERICAS          5554         5084             95         5501
# EMEA              3925         3030             97         3896
# N ASIA           11136         9039            100        11047
# S ASIA           27904        24373            100        27817
# SE ASIA          29272        25978             98        29195
#
#          Migrant Workers Total Workers excluding immigrants
# Region
# AMERICAS              76                               5554
# EMEA                 100                               3914
# N ASIA               100                              11136
# S ASIA                99                              27904
# SE ASIA              100                              29272

# %%
# the minimum  workers in details (each region)
res14 = data.groupby("Region").agg({"Total Workers": "min", "Line Workers": "min", "Female Workers":"min","Migrant Workers":"min" })
res14
# Out:
#          Total Workers Line Workers Female Workers Migrant Workers
# Region
# AMERICAS            21           10              0               0
# EMEA                11            8             15               0
# N ASIA               2            1              0               0
# S ASIA              28           20              0               0
# SE ASIA              2            1              0               0

# %%
data.describe()
# Out:
#                          Factory Name    Factory Type Product Type Brand  \
# count                             636             636          636   636
# unique                            632               3            3     2
# top     PT Victory Chingluh Indonesia  FINISHED GOODS      Apparel  Nike
# freq                                2             461          354   602
#
#             Events Supplier Group        City      State  Country  Region  \
# count          636            636         635        636      636     636
# unique           1            296         470        188       36       5
# top     Collegiate       FENG TAY  Phnom Penh  Guangdong  Vietnam  N ASIA
# freq           636             16          11         49      159     213
#
#         Total Workers  Line Workers  Female Workers  Migrant Workers  \
# count             636           636             636              636
# unique            526           511              95               61
# top                 2             1               0                0
# freq                7             9              30              477
#
#         Male Workers  Total Workers excluding immigrants
# count            636                                 636
# unique           542                                 532
# top                1                                 -98
# freq               9                                   5
