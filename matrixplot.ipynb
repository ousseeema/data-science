# %% [markdown]
# <a href="https://colab.research.google.com/github/ousseeema/data-science/blob/main/matrixplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips= sns.load_dataset('tips')
flights = sns.load_dataset('flights')
# some reminder's
#sns.histplot(x = 'total_bill', data = tips, kde= True)
#sns.jointplot(x = "day", y = "total_bill", data= tips)
#sns.pairplot(tips, hue="smoker")

#sns.barplot(x= "day", y = "total_bill", data = tips , estimator="sum", hue= "smoker")
#sns.boxplot(x= "day", y = "total_bill", data = tips , hue = "smoker", )
#sns.countplot(x= "day", data= tips)
#sns.stripplot(x="day", y = "total_bill", data = tips , dodge= True , jitter = True , hue = "smoker")
#sns.violinplot(x="day", y = "total_bill", data = tips  )
#sns.swarmplot(x="day", y = "total_bill", data = tips ,dodge=True,)
#sns.catplot(x="day", y = "total_bill", data = tips , kind = '')
#fig = plt.figure()
#ax1 = fig.add_subplot(2,2,1)
#ax2 = fig.add_subplot(2,2,3)
#ax1.hist(x = 'total_bill', data = tips)
#ax2.plot(tips["day"], tips['tip'])
#plt.tight_layout()

# %%
fc = flights.pivot_table(index="month", columns="year", values="passengers")
sns.heatmap(fc, cmap="magma", linecolor="white", linewidth=1)
# Out:
# <ipython-input-78-b98260888a21>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fc = flights.pivot_table(index="month", columns="year", values="passengers")
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(fc)

# %%
tc = tips.corr(numeric_only=True)
sns.heatmap(tc, cmap="magma")
# Out:
# <Axes: >

# %%
sns.clustermap(tc)
